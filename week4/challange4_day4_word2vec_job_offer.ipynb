# %%
import pandas as pd

from gensim.utils import simple_preprocess
from gensim.models import Word2Vec
from gensim.models.phrases import Phrases, Phraser

from ast import literal_eval

# %%
cd '/content/drive/My Drive/Colab Notebooks/challange/week4'
# Out:
# /content/drive/My Drive/Colab Notebooks/challange/week4

# %%
df = pd.read_csv('data/job_ofer.csv')
df.shape
# Out:
# (36109, 8)

# %%
df.head()
# Out:
#                                         title  ...                           industries
# 0                   Machine Learning Engineer  ...  Information Technology and Services
# 1  Deep Learning Applied Researcher - Chicago  ...  Information Technology and Services
# 2                   Machine Learning Engineer  ...  Information Technology and Services
# 3           Machine Learning / Data Scientist  ...  Information Technology and Services
# 4                             Cloud Architect  ...  Information Technology and Services
#
# [5 rows x 8 columns]

# %%
# Word2Vec

# %%
corpus = df['title'].map(simple_preprocess)

# %%
model = Word2Vec(corpus, size=100, window=2, min_count=1)

# %%
model.wv.most_similar('machine')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('deep', 0.9402987957000732),
#  ('scientists', 0.8640309572219849),
#  ('big', 0.845497190952301),
#  ('edge', 0.834496021270752),
#  ('personalization', 0.8292109966278076),
#  ('bentonville', 0.8263026475906372),
#  ('nlp', 0.8259617686271667),
#  ('inference', 0.824763834476471),
#  ('experiments', 0.8175926208496094),
#  ('python', 0.8174095153808594)]

# %%
# Title + phrases

# %%
title_corpus = df['title'].map(simple_preprocess)

title_bigram = Phraser( Phrases(title_corpus, min_count=1, threshold=1) )

# %%
title_bigram[ simple_preprocess('Deep Learning Applied Researcher - Chicago') ]
# Out:
# ['deep_learning', 'applied', 'researcher', 'chicago']

# %%
title_corpus_phrases = [ title_bigram[sent] for sent in title_corpus]

model = Word2Vec(title_corpus_phrases, size=100, window=2, min_count=1)

# %%
model.wv.most_similar('machine')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('engineer_go', 0.9565683007240295),
#  ('category_manager', 0.9564213752746582),
#  ('analyst_immediate', 0.9562027454376221),
#  ('products', 0.9559204578399658),
#  ('in_vermont', 0.9558045864105225),
#  ('strategies', 0.9557765126228333),
#  ('gb', 0.9556193351745605),
#  ('level', 0.9555582404136658),
#  ('la_canada', 0.955501139163971),
#  ('desk', 0.9554449915885925)]

# %%
def prepare_corpus(corpus, bigram):
  for sent in corpus:
    yield bigram[sent] + sent

# %%
ext_corp = list(prepare_corpus(title_corpus, title_bigram))
title_model = Word2Vec( ext_corp, size=100, window=2, min_count=1 )

# %%
title_model.wv.most_similar('machine_learning')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('computer_vision', 0.9845678806304932),
#  ('deep', 0.977944016456604),
#  ('deep_learning', 0.9764058589935303),
#  ('ml', 0.975455641746521),
#  ('artificial_intelligence', 0.9752612709999084),
#  ('learning', 0.9741491675376892),
#  ('engineer_personalization', 0.974045991897583),
#  ('nlp', 0.9724612236022949),
#  ('data_engineer', 0.9703434109687805),
#  ('rockville', 0.9694668650627136)]

# %%
descr_corpus = df['description'].map(simple_preprocess)
descr_bigram = Phraser( Phrases(descr_corpus, min_count=1, threshold=1) )

# %%
#ext_descr_corp = list(prepare_corpus(descr_corpus, descr_bigram))
descr_model = Word2Vec( descr_corpus, size=100, window=2, min_count=1 )

# %%
descr_model.wv.most_similar('python')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('java', 0.8457391858100891),
#  ('scala', 0.8184995651245117),
#  ('javascript', 0.7774099111557007),
#  ('matlab', 0.7694929838180542),
#  ('scripting', 0.7446565628051758),
#  ('nodejs', 0.7327423095703125),
#  ('ruby', 0.7310747504234314),
#  ('vba', 0.7191867828369141),
#  ('stata', 0.717115044593811),
#  ('sql', 0.7103444337844849)]

# %%
title_model.wv.most_similar('nlp')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('ml', 0.9938449263572693),
#  ('artificial_intelligence', 0.9915289878845215),
#  ('deep_learning', 0.988430917263031),
#  ('computer_vision', 0.9870984554290771),
#  ('deep', 0.9870568513870239),
#  ('big_data', 0.9849032163619995),
#  ('computer', 0.9834546446800232),
#  ('scientist_ii', 0.9804015159606934),
#  ('corrosion', 0.9793272018432617),
#  ('engineer_personalization', 0.979071855545044)]

# %%
for line in df.sample()['description'].map(literal_eval).values[0]:
  print(line)
  print("")
# Out:
# About Uber
#
# We’re changing the way people think about transportation. Not that long ago we were just an app to request premium black cars in a few metropolitan areas. Now we’re a part of the logistical fabric of more than 600 cities around the world. Whether it’s a ride, a sandwich, or a package, we use technology to give people what they want, when they want it.
#
# For the people who drive with Uber, our app represents a flexible new way to earn money. For cities, we help strengthen local economies, improve access to transportation, and make streets safer.
#
# And that’s just what we’re doing today. We’re thinking about the future, too. With teams working on autonomous trucking and self-driving cars, we’re in for the long haul. We’re reimagining how people and things move from one place to the next.
#
# About The Role
#
# As a reliability test engineer on the V&V team, you will participate in requirements engineering, develop hardware test plans, build our new test lab, develop test cases, design/build test fixtures, execute reliability tests and document/analyze results to validate components and systems.
#
# What You’ll Do
#
# Characterize and test mechanical, thermal, and vibrational properties of self-driving vehicle compute systems, cameras, lidar, and mechanical structures.
#
# Design, build and maintain mechanical test fixtures.
#
# Develop test cases to validate reliability of components
#
# Develop tools and methods to automate testing for rapid deployment
#
# Perform quantitative tests to determine how temperature, humidity, and mechanical stress impact subsystem performance
#
# Write test scripts in high-level languages like Python, LabView or Matlab to automate test equipment.
#
# Utilize data acquisition systems to collect data, then analyze and report results.
#
# Maintain engineering processes and documentation.
#
# What You’ll Need
#
# Creative problem solving
#
# Prototype testing experience
#
# Detailed experience with reliability tests (thermal, shock, vib, UV, EMC, etc)
#
# Broad general mechanical and electrical engineering knowledge
#
# Familiarity with circuits and software control of instruments
#
# Great data gathering and analytical skills
#
# BS in Physics, ME, EE, or a related field and 5 years of work experience or
#
# Advanced degree (Masters, Ph.D.) in a relevant technical field and 3 years of relevant work experience.
#
# Bonus Points If
#
# Experience with safety-critical hardware systems and components
#
# Understanding of automotive applications and standards
#
# Experience in agile project environments
#
# CAN bus vehicle standard familiarity
#
# Lab management experience
#
# About The Team
#
# At the Advanced Technologies Group (ATG), we are building technologies that will transform the way the world moves. Our teams in Pittsburgh, San Francisco, Phoenix, and Toronto are dedicated to mapping, software and hardware development, vehicle safety, and operations for self-driving technology. Our teams are passionate about developing a self-driving system that will one day move people and things around more safely, efficiently, and cost effectively.
#
# Our hardware team's role is to develop and integrate UBER self-driving technologies into existing and future vehicle platforms of multiple OEM’s at scale.
